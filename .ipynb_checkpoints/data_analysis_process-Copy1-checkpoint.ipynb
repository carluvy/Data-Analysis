# %% [markdown]
# # Project: Investigating TMDB Movies Dataset

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1">Introduction</a></span></li><li><span><a href="#Data-Wrangling" data-toc-modified-id="Data-Wrangling-2">Data Wrangling</a></span><ul class="toc-item"><li><span><a href="#General-Properties" data-toc-modified-id="General-Properties-2.1">General Properties</a></span><ul class="toc-item"><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-2.1.1">Conclusion</a></span></li></ul></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-2.2">Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Rename-production_companies-to-prod_companies" data-toc-modified-id="Rename-production_companies-to-prod_companies-2.2.1">Rename production_companies to prod_companies</a></span></li><li><span><a href="#Drop-missing-values" data-toc-modified-id="Drop-missing-values-2.2.2">Drop missing values</a></span></li><li><span><a href="#Drop-duplicate-values" data-toc-modified-id="Drop-duplicate-values-2.2.3">Drop duplicate values</a></span></li><li><span><a href="#Drop-the-id,-the-imdb_id,-homepage,-and-overview-columns" data-toc-modified-id="Drop-the-id,-the-imdb_id,-homepage,-and-overview-columns-2.2.4">Drop the id, the imdb_id, homepage, and overview columns</a></span></li><li><span><a href="#Convert-release_date-from-string-to-datetime" data-toc-modified-id="Convert-release_date-from-string-to-datetime-2.2.5">Convert release_date from string to datetime</a></span></li><li><span><a href="#Convert-release_year-from-string-to-datetime" data-toc-modified-id="Convert-release_year-from-string-to-datetime-2.2.6">Convert release_year from string to datetime</a></span></li><li><span><a href="#Convert-budget--from-integer-to-float" data-toc-modified-id="Convert-budget--from-integer-to-float-2.2.7">Convert budget  from integer to float</a></span></li><li><span><a href="#Convert-revenue--from-integer-to-float" data-toc-modified-id="Convert-revenue--from-integer-to-float-2.2.8">Convert revenue  from integer to float</a></span></li><li><span><a href="#Drop-zero-values-from-the-revenue-column" data-toc-modified-id="Drop-zero-values-from-the-revenue-column-2.2.9">Drop zero values from the revenue column</a></span></li><li><span><a href="#Check-for-Outliers" data-toc-modified-id="Check-for-Outliers-2.2.10">Check for Outliers</a></span><ul class="toc-item"><li><span><a href="#Boxplots-to-check-for-outliers-in-numeric-values" data-toc-modified-id="Boxplots-to-check-for-outliers-in-numeric-values-2.2.10.1">Boxplots to check for outliers in numeric values</a></span></li><li><span><a href="#Method-to-calculate-the-interquartile-range" data-toc-modified-id="Method-to-calculate-the-interquartile-range-2.2.10.2">Method to calculate the interquartile range</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3">Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#What-kinds-of-properties-are-associated-with-movies-that-have-high-revenues?" data-toc-modified-id="What-kinds-of-properties-are-associated-with-movies-that-have-high-revenues?-3.1">What kinds of properties are associated with movies that have high revenues?</a></span><ul class="toc-item"><li><span><a href="#Scatter-plots-of-revenue-against-various-features" data-toc-modified-id="Scatter-plots-of-revenue-against-various-features-3.1.1">Scatter plots of revenue against various features</a></span></li><li><span><a href="#There-is-no-clear-correlation-between-popularity-and-revenue-but-we-notice-a-bit-of-clustering-skewed-to-the-right.-Furthermore,-there-are-a-few-outliers-in-both-features.-Let's-look-at-budget-in-the-next-cell" data-toc-modified-id="There-is-no-clear-correlation-between-popularity-and-revenue-but-we-notice-a-bit-of-clustering-skewed-to-the-right.-Furthermore,-there-are-a-few-outliers-in-both-features.-Let's-look-at-budget-in-the-next-cell-3.1.2">There is no clear correlation between popularity and revenue but we notice a bit of clustering skewed to the right. Furthermore, there are a few outliers in both features. Let's look at budget in the next cell</a></span></li><li><span><a href="#There-is-some-clustering-around-the-features-but-no-clear-correlation-between-them.-Furthermore,-there-are-a-few-outliers-in-both-features.-We'll-explore-runtime-in-the-next-cell" data-toc-modified-id="There-is-some-clustering-around-the-features-but-no-clear-correlation-between-them.-Furthermore,-there-are-a-few-outliers-in-both-features.-We'll-explore-runtime-in-the-next-cell-3.1.3">There is some clustering around the features but no clear correlation between them. Furthermore, there are a few outliers in both features. We'll explore runtime in the next cell</a></span></li><li><span><a href="#There-is-no-correlation-between-runtime-and-revenue.-Furthermore,-there-are-a-few-outliers-in-both-features." data-toc-modified-id="There-is-no-correlation-between-runtime-and-revenue.-Furthermore,-there-are-a-few-outliers-in-both-features.-3.1.4">There is no correlation between runtime and revenue. Furthermore, there are a few outliers in both features.</a></span></li></ul></li></ul></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-4">Conclusions</a></span></li></ul></div>

# %% [markdown]
# ### Introduction
#
# In this project we'll be analyzing a dataset that contains information about movies collected from The Movie Database (TMDB).
# We'll be interested in finding out:
# What are the trends among the movies that generated high revenues overall?

# %%
# Import Packages

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Data Wrangling
#
# #### General Properties

# %%
def load_any(file):
    return file

# %%
# Loading TMDB Movies Data

df = load_any(pd.read_csv('tmdb-movies.csv'))

# %%
# Preview the first five rows of the Dataset

df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.groupby('original_title').revenue.mean()
# Out:
# original_title
# $5 a Day                                     0.0
# $9.99                                        0.0
# '71                                    1625847.0
# (500) Days of Summer                  60722734.0
# (T)Raumschiff Surprise - Periode 1           0.0
#                                          ...
# ì•„ê¸°ì™€ ë‚˜                                0.0
# ì‹ ì˜ í•œ ìˆ˜                                0.0
# í¬í™” ì†ìœ¼ë¡œ                               0.0
# í˜•ì‚¬ Duelist                               0.0
# í•˜ìš¸ë§                                     0.0
# Name: revenue, Length: 10571, dtype: float64

# %%
# Preview the last five rows of the Dataset
df.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %% [markdown]
# After previewing the dataset in the steps above, we found out that the dataset is indeed in csv format.
# Next, we'll check the structure of the dataset. Also looking at the last five rows of the data,
# we realize that the revenue and budget have some rows with 0 as the value.

# %%
# View how many columns and rows are in the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %% [markdown]
# According to the two cells above, the dataset has a total of 10,866 rows, and 21 columns.
# Next we will proceed to checking the data types.

# %%
# View the data types of the columns of the Dataset
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %% [markdown]
# The cell above shows the columns and their data types.
# We will proceed to checking if the dataset has duplicate values.

# %%
# View number of rows with duplicate values
df.duplicated().sum()
# Out:
# 1

# %%
# Filter duplicate row in all columns
df.loc[df.original_title == 'TEKKEN']
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2089  42194  tt0411951     0.59643  30000000   967000         TEKKEN
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2089  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2089  Dwight H. Little  Survival is no game  ...
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2089  In the year of 2039, after World Wars destroy ...      92
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2089  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
# ...

# %% [markdown]
# The two cells above indicate that the entire dataset has only one duplicate.
# The record for the original_title 'TEKKEN' was  entered twice.
# Next step will be checking for missing values.

# %%
# Check for missing values in the dataset
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.genres.replace("\|", ",", regex=True)
# Out:
# 0        Action,Adventure,Science Fiction,Thriller
# 1        Action,Adventure,Science Fiction,Thriller
# 2               Adventure,Science Fiction,Thriller
# 3         Action,Adventure,Science Fiction,Fantasy
# 4                            Action,Crime,Thriller
#                            ...
# 10861                                  Documentary
# 10862                       Action,Adventure,Drama
# 10863                               Mystery,Comedy
# 10864                                Action,Comedy
# 10865                                       Horror
# Name: genres, Length: 10866, dtype: object

# %%
plt.plot(df.original_title);

# %%
movies_df.cast.apply(lambda x : "{:,}".format(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 movies_df.cast.apply(lambda x : "{:,}".format(x))
#
# NameError: name 'movies_df' is not defined

# %% [markdown]
# The cell above shows that the dataset has missing values in imdb_id, cast, homepage,
# director, tagline, keywords, overview, genres, and production_companies columns.

# %% [markdown]
# ##### Conclusion
# Some of the columns in the dataset have practical data types that correctly describe their values
# but others like the release_date and release_year columns are not formatted as date types.
# In addition, the revenue and budget columns are not uniform to their adj counterparts that are in a float datatype.
# I found out that the dataset has one duplicate value that represents a record that was entered twice.
# There are multiple rows that have missing values, and one column name that needs to be renamed for readability because it is too long.
# I also mentioned that the revenue and budget columns seem to have 0 in some of their rows;
# this could pose a potential case of outliers or abnormalities in the dataset, so we''ll take necessary steps to investigate that.
# For the purpose of this investigation, the id, imdb_id, homepage, and overview columns are not necessary.
# Furthermore, because we will be using the revenue and budget features as metrics, it would be preferable for all movies to have bugdet and revenue values that are more than zero.
#
# The columns and rows represent:
# id - a general id for each movie,
# imdb_id - an imdb id for each movie,
# popularity - number of user ratings for each movie,
# budget - the cost of making of each movie in USD,
# revenue - revenue generated from each movie in USD,
# original_title - the original title of each movie,
# cast - cast members of each movie (because some movies have more than one cast member,
# the names are separated by a pipe),
# homepage - the homepage of each movie online,
# director - the director of each movie,
# tagline - the tagline used to describe each movie,
# keywords - the keywords in each movie,
# overview - the overview of each movie,
#
# (because some movies have more than one genre, the genres are separated by a pipe),
# production_companies - companies that produced each movie,
# release_date - the release date of each movie in dd/mm/yy format,
# vote_counts - number of votes for each movie,
# vote_average - average number of votes for each movie,
# release_year - the release year of each movie,
# budget_adj - the budget of each movie in terms of 2010 USD accounting for inflation over time,
# revenue_adj - the revenue of each movie in terms of 2010 USD accounting for inflation over time,
#
# In the following cells, we will be taking steps to:
#  rename the long column name
#  drop missing values
#  drop the duplicate values
#  drop id column
#  drop imdb_id column
#  drop the overview column
#  drop the homepage column
#  convert release_date from object to datetime
#  convert release_year from integer to datetime
#  convert budget and revenue from interger to float
#  drop 0 values in the revenue column
#  drop 0 values in the budget column
#  investigate the existence of outliers

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# ##### Rename production_companies to prod_companies

# %%
df.rename(columns={'production_companies': 'prod_companies'}, inplace=True)

# %%
# check if the column has been renamed
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'prod_companies', 'release_date', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %% [markdown]
# ##### Drop missing values

# %%
df.dropna(inplace=True)

# %%
# check if there are missing values
df.isnull().sum()
# Out:
# id                0
# imdb_id           0
# popularity        0
# budget            0
# revenue           0
# original_title    0
# cast              0
# homepage          0
# director          0
# tagline           0
# keywords          0
# overview          0
# runtime           0
# genres            0
# prod_companies    0
# release_date      0
# vote_count        0
# vote_average      0
# release_year      0
# budget_adj        0
# revenue_adj       0
# dtype: int64

# %% [markdown]
# ##### Drop duplicate values

# %%
df.drop_duplicates(inplace=True)

# %%
# check if there are duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Drop the id, the imdb_id, homepage, and overview columns

# %%
df.drop(['id', 'imdb_id', 'homepage', 'overview'], axis =1, inplace=True)

# %%
# Check if the columns have been dropped
df.head(1)
# Out:
#    popularity     budget     revenue  original_title  \
# 0   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           keywords  \
# 0  The park is open.  monster|dna|tyrannosaurus rex|velociraptor|island
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                       prod_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09

# %% [markdown]
# ##### Convert release_date from string to datetime

# %%
df['release_date'] = pd.to_datetime(df.release_date)

# %% [markdown]
# ##### Convert release_year from string to datetime

# %%
df['release_year'] = pd.to_datetime(df.release_year)

# %% [markdown]
# ##### Convert budget  from integer to float

# %%
df['budget'] = df['budget'].astype(float)

# %% [markdown]
# ##### Convert revenue  from integer to float

# %%
df['revenue'] = df['revenue'].astype(float)

# %%
# confirm successful datatype convertion
df.dtypes
# Out:
# popularity               float64
# budget                   float64
# revenue                  float64
# original_title            object
# cast                      object
# director                  object
# tagline                   object
# keywords                  object
# runtime                    int64
# genres                    object
# prod_companies            object
# release_date      datetime64[ns]
# vote_count                 int64
# vote_average             float64
# release_year      datetime64[ns]
# budget_adj               float64
# revenue_adj              float64
# dtype: object

# %%
df.shape
# Out:
# (1992, 17)

# %% [markdown]
# ##### Drop zero values from the revenue column

# %%
df.drop(df[df['revenue'] == 0.0].index, inplace=True)

# %%
df.drop(df[df['budget'] == 0.0].index, inplace=True)

# %%
df.shape
# Out:
# (1287, 17)

# %% [markdown]
# After cleaning up the dataset, we have reduced the dataset to 1287 rows and 17 columns.
# Let's view the distribution stats to see if we can spot outliers.

# %% [markdown]
# ##### Check for Outliers

# %%
df.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1287.000000  1.287000e+03  1.287000e+03  1287.000000  1287.000000
# mean      1.786022  5.200349e+07  1.762444e+08   110.273504   947.266511
# std       2.172137  5.514540e+07  2.538156e+08    18.811369  1255.476215
# min       0.010335  1.000000e+00  4.300000e+01    63.000000    10.000000
# 25%       0.664783  1.400000e+07  2.565097e+07    97.000000   179.000000
# 50%       1.152354  3.200000e+07  8.208716e+07   107.000000   439.000000
# 75%       2.125342  7.000000e+07  2.140694e+08   121.000000  1173.000000
# max      32.985763  4.250000e+08  2.781506e+09   201.000000  9767.000000
#
#        vote_average    budget_adj   revenue_adj
# count   1287.000000  1.287000e+03  1.287000e+03
# mean       6.279487  5.462994e+07  1.991775e+08
# std        0.795955  5.525463e+07  2.968515e+08
# min        2.200000  9.693980e-01  4.300000e+01
# 25%        5.800000  1.519180e+07  2.764890e+07
# ...

# %% [markdown]
# From the distribution above, we can notice some gaps in the popularity, revenue, and runtime colummns.
# Let's investigate more in the next few cells to see if there are outliers...

# %% [markdown]
# ###### Boxplots to check for outliers in numeric values

# %%
# a function that takes in the x value to be plotted
def make_boxplot(x_value):
    
    # assigns a value to the result of the sns boxplot function
    box_plot = sns.boxplot(x= x_value)
    
    #returns a boxplot
    return box_plot

# %%
make_boxplot(df.revenue);

# %% [markdown]
# There are some values that are scattered away from the rest. We can infer that the value on the far right is the maximum revenue. This may affect the resuts of our analysis. Next we'll do the same for the rest of the columns...

# %%
make_boxplot(df.budget);

# %%
make_boxplot(df.runtime);

# %%
make_boxplot(df.revenue_adj);

# %%
make_boxplot(df.budget_adj);

# %%
make_boxplot(df.popularity);

# %%
make_boxplot(df.vote_count);

# %%
make_boxplot(df.vote_average);

# %% [markdown]
# According to the visulas above, except for the runtime and vote average columns, all the other features are skewed to the right. There are outliers in the dataset and some of them especially in the revenue column, may affect our analysis. Next up, we will try to find and treat the outliers.
# Because the nature of this analysis, I will not perform any imputation on the outliers but rather, I will drop all the outliers.

# %% [markdown]
# In the following cell, we'll try to find the interquartile range for each of the numerical features.

# %% [markdown]
# ###### Method to calculate the interquartile range

# %%
def remove_outliers(data):
    # calculate the 25% and 75% distributions using pandas
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    
    # subract the 25% from the 75% to get the interquartile range
    IQR = Q3 - Q1
    
    # define a condition to filter out outliers
    # if the value is less than 25%-(1.5IQR) then it's an outlier on the lower end
    # and if the value is more than 75%+(1.5IQR) then it's an outlier on the upper end
    
    below_iqr = data < (Q1 - 1.5 * IQR)
    above_iqr = data > (Q3 + 1.5 * IQR)
    
    # we generate a new dataframe, deleting values that are below or above the iqr
    data = data[~(below_iqr | above_iqr)]
    
    # returns the dataframe we just created
    return data

# %% [markdown]
# Make a copy of the dataset so that I can extract and use the numerical values to eliminate outliers. After removing the outliers, I will combine the datasets again so that we will have all features to explore. Of course, this shrinks our dataset.

# %%
numerical_df = df.copy()

# %%
numerical_df.shape
# Out:
# (1287, 8)

# %%
numerical_df.head(1)
# Out:
#    popularity       budget       revenue  original_title  \
# 0   32.985763  150000000.0  1.513529e+09  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           keywords  \
# 0  The park is open.  monster|dna|tyrannosaurus rex|velociraptor|island
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                       prod_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09        5562
#
#    vote_average                  release_year    budget_adj   revenue_adj
# 0           6.5 1970-01-01 00:00:00.000002015  1.379999e+08  1.392446e+09

# %%
# drop all non-numerical values from the dataframe
numerical_df.drop(['release_year','tagline', 'genres', 
                   'keywords', 'director', 'cast', 'original_title', 
                   'prod_companies', 'release_date'], axis=1, inplace=True)

# %%
# confirm that we indeed only have numerical values
numerical_df.dtypes
# Out:
# popularity      float64
# budget          float64
# revenue         float64
# runtime           int64
# vote_count        int64
# vote_average    float64
# budget_adj      float64
# revenue_adj     float64
# dtype: object

# %%
# let's check the structure of our dataset 
# to see if it changes when we remove the outliers
numerical_df.shape
# Out:
# (1287, 8)

# %%
# call the function that removes outliers on the numerical_df
numerical_df = remove_outliers(numerical_df)

# %%
# confirm the number of samples in the dataset has changed
# after removing the outliers
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 0 to 10760
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   popularity    1189 non-null   float64
#  1   budget        1205 non-null   float64
#  2   revenue       1167 non-null   float64
#  3   runtime       1258 non-null   float64
#  4   vote_count    1163 non-null   float64
#  5   vote_average  1274 non-null   float64
#  6   budget_adj    1222 non-null   float64
#  7   revenue_adj   1154 non-null   float64
# dtypes: float64(8)
# memory usage: 90.5 KB

# %% [markdown]
# After deleting the outliers from our dataset,
# we realize that the dataset has some rows with missing values.
# I will now drop missing values from the dataset

# %%
# confirm if we have missing values
numerical_df.isnull().sum()
# Out:
# popularity       98
# budget           82
# revenue         120
# runtime          29
# vote_count      124
# vote_average     13
# budget_adj       65
# revenue_adj     133
# dtype: int64

# %% [markdown]
# Because I want to use all features from my dataset to explore the features that contribute
# to high revenues in certain movies,
# I will combine the numerical dataframe with the missing features from the original cleaned data.
#
# Before combining them, I will first of all drop the numerical values from the original dataset.
# I am combining them before dropping the missing values so that they will both have the same shape.

# %%
df.shape
# Out:
# (1287, 17)

# %%
df.drop(['revenue', 'revenue_adj', 'budget_adj', 'budget', 'popularity', 
              'runtime', 'vote_count', 'vote_average'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1287, 9)

# %% [markdown]
# Now we can combine the dataframes, it should go back to having 17 columns.

# %%
# use concat to combine dataframes
df_concatenated = pd.concat([numerical_df, df], axis='columns')

# %%
# confirm tha it worked
df_concatenated.shape
# Out:
# (1287, 17)

# %% [markdown]
# The data has been combined corretly into 1287 rows and 17 columns.

# %%
df_concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 28 to 10689
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   popularity      1031 non-null   float64
#  1   budget          1031 non-null   float64
#  2   revenue         1031 non-null   float64
#  3   runtime         1031 non-null   float64
#  4   vote_count      1031 non-null   float64
#  5   vote_average    1031 non-null   float64
#  6   budget_adj      1031 non-null   float64
#  7   revenue_adj     1031 non-null   float64
#  8   original_title  1287 non-null   object
#  9   cast            1287 non-null   object
#  10  director        1287 non-null   object
#  11  tagline         1287 non-null   object
#  12  keywords        1287 non-null   object
#  13  genres          1287 non-null   object
#  14  prod_companies  1287 non-null   object
#  15  release_date    1287 non-null   datetime64[ns]
# ...

# %% [markdown]
# As expected our data has missing values which we'll drop now.

# %%
# drop missing values
df_concatenated.dropna(inplace=True)

# %%
df_concatenated.isnull().sum()
# Out:
# popularity        0
# budget            0
# revenue           0
# runtime           0
# vote_count        0
# vote_average      0
# budget_adj        0
# revenue_adj       0
# original_title    0
# cast              0
# director          0
# tagline           0
# keywords          0
# genres            0
# prod_companies    0
# release_date      0
# release_year      0
# dtype: int64

# %%
df_concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1031 entries, 28 to 10760
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   popularity      1031 non-null   float64
#  1   budget          1031 non-null   float64
#  2   revenue         1031 non-null   float64
#  3   runtime         1031 non-null   float64
#  4   vote_count      1031 non-null   float64
#  5   vote_average    1031 non-null   float64
#  6   budget_adj      1031 non-null   float64
#  7   revenue_adj     1031 non-null   float64
#  8   original_title  1031 non-null   object
#  9   cast            1031 non-null   object
#  10  director        1031 non-null   object
#  11  tagline         1031 non-null   object
#  12  keywords        1031 non-null   object
#  13  genres          1031 non-null   object
#  14  prod_companies  1031 non-null   object
#  15  release_date    1031 non-null   datetime64[ns]
# ...

# %% [markdown]
# We can tell that the data has now shrunk by over 200 rows. This was expected after trimming outliers and dropping missing values that resulted from trimming outliers.

# %% [markdown]
# Now, lets check if the distribution still displays correctly.
# For example: the popularity column should not have a value that
# is less than -1.5260555 or more than 4.3161835

# %%
# check that trimming outliers worked correctly
df_concatenated.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1031.000000  1.031000e+03  1.031000e+03  1031.000000  1031.000000
# mean      1.189673  3.602759e+07  9.075476e+07   107.011639   515.160039
# std       0.796456  3.280397e+07  9.568512e+07    15.272981   516.075146
# min       0.010335  1.000000e+00  4.300000e+01    63.000000    10.000000
# 25%       0.598769  1.100000e+07  1.785102e+07    96.000000   141.000000
# 50%       1.002527  2.600000e+07  5.919213e+07   105.000000   332.000000
# 75%       1.556623  5.000000e+07  1.325476e+08   116.000000   712.500000
# max       4.215642  1.500000e+08  4.846358e+08   157.000000  2635.000000
#
#        vote_average    budget_adj   revenue_adj
# count   1031.000000  1.031000e+03  1.031000e+03
# mean       6.187294  3.818432e+07  9.932853e+07
# std        0.715517  3.453230e+07  1.078245e+08
# min        4.300000  9.693980e-01  4.300000e+01
# 25%        5.700000  1.187594e+07  1.920803e+07
# ...

# %% [markdown]
# Everything seems to have worked as expected.
# Now it's time to save the cleaned data.

# %%
# Save cleaned data in another csv file
df_concatenated.to_csv('tmdb_movies_version2.csv', index=False)

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### What kinds of properties are associated with movies that have high revenues?

# %% [markdown]
# In this section, I'll perform exploratory analysis on the previously cleaned data in order to answer our first question that is above. To do that, we'll explore scatter plots of the revenue column, against budget, revenue, and runtime features.
#
# Let's start by loading data and checking if it is in the correct format.

# %%
# load previously cleaned data
def load_clean_data():
    clean_data = load_any(pd.read_csv('tmdb_movies_version2.csv'))
    return clean_data

# %%
movies_df = load_clean_data()
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031 entries, 0 to 1030
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   popularity      1031 non-null   float64
#  1   budget          1031 non-null   float64
#  2   revenue         1031 non-null   float64
#  3   runtime         1031 non-null   float64
#  4   vote_count      1031 non-null   float64
#  5   vote_average    1031 non-null   float64
#  6   budget_adj      1031 non-null   float64
#  7   revenue_adj     1031 non-null   float64
#  8   original_title  1031 non-null   object
#  9   cast            1031 non-null   object
#  10  director        1031 non-null   object
#  11  tagline         1031 non-null   object
#  12  keywords        1031 non-null   object
#  13  genres          1031 non-null   object
#  14  prod_companies  1031 non-null   object
#  15  release_date    1031 non-null   object
#  16  release_year    1031 non-null   object
# ...

# %% [markdown]
# ##### Scatter plots of revenue against various features

# %%
# A method to create scatter plots
def plot_scatter(x_value, y_value):
    colors = np.array([range(0, len(movies_df.index))])
    plt.figure(figsize=(10,8))
    return plt.scatter(x_value, y_value, c=colors, cmap='viridis')

# %%
movies_df.revenue.sum()
# Out:
# 93568153914.0

# %%
movies_df.popularity.sum()
# Out:
# 1226.552813

# %%
# show relationship between popularity and revenue
plot_scatter(movies_df.popularity, movies_df.revenue)
plt.xlabel("popularity")
plt.ylabel("revenue");
plt.colorbar();

# %% [markdown]
# ##### There is no clear correlation between popularity and revenue but we notice a bit of clustering skewed to the right. Furthermore, there are a few outliers in both features. Let's look at budget in the next cell

# %%
# show relationship between budget and revenue
plot_scatter(movies_df.budget, movies_df.revenue)
plt.xlabel("budget")
plt.ylabel("revenue")
plt.colorbar();

# %% [markdown]
# ##### There is some clustering around the features but no clear correlation between them. Furthermore, there are a few outliers in both features. We'll explore runtime in the next cell

# %%
# show relationship between runtime and revenue
plot_scatter(movies_df.runtime, movies_df.revenue)
plt.xlabel("runtime")
plt.ylabel("revenue")
plt.colorbar();

# %% [markdown]
# ##### There is no correlation between runtime and revenue. Furthermore, there are a few outliers in both features.

# %% [markdown]
# In the above exploration of the revenue feature against popularity, runtime, and budget; I noticed that in all cases there were outliers in the data. Because of this, we will plot some boxplots to visualize the outliers.

# %% [markdown]
# To see the if there is a correlation between budget, runtime, popularity, and revenue,
# I am going to create a new column that will hold groups of data by popularity ranking shown in the cell below.

# %%
# distribution stats for the revenue column
movies_df.revenue.describe()
# Out:
# count    1.031000e+03
# mean     9.075476e+07
# std      9.568512e+07
# min      4.300000e+01
# 25%      1.785102e+07
# 50%      5.919213e+07
# 75%      1.325476e+08
# max      4.846358e+08
# Name: revenue, dtype: float64

# %% [markdown]
# Create a list of bin edges that will be used to group data into low, high, medium, medium high.

# %%
# bin edges that will be used to "cut" the data into groups of
# (min, 25%, 50%, 75%, max)
bin_edges = [4.300000e+01, 1.785102e+07, 5.919213e+07, 1.325476e+08, 4.846358e+08]

# %%
# name each ranking category
bin_names = ['High','Medium High','Medium', 'Low' ]

# %%
# add a new column for popularity ranking and cut popularity column data into labeled bins
movies_df['revenue_rank'] = pd.cut(movies_df['revenue'], bin_edges, labels=bin_names)

# %%
# view the new column
movies_df.head(1)
# Out:
#    popularity      budget     revenue  runtime  vote_count  vote_average  \
# 0    4.062293  20000000.0  88346473.0    128.0      1559.0           7.8
#
#      budget_adj   revenue_adj original_title  \
# 0  1.839999e+07  8.127872e+07      Spotlight
#
#                                                 cast      director  \
# 0  Mark Ruffalo|Michael Keaton|Rachel McAdams|Lie...  Tom McCarthy
#
#                                tagline  \
# 0  Break the story. Break the silence.
#
#                                       keywords                  genres  \
# 0  child abuse|journalism|judge|florida|boston  Drama|Thriller|History
#
#                                       prod_companies release_date  \
# 0  Participant Media|Open Road Films|Anonymous Co...   2015-11-06
#
#                     release_year revenue_rank
# 0  1970-01-01 00:00:00.000002015       Medium

# %% [markdown]
# Now it's time to use the grouped data to visualize the three features together.
# revenue, budget, runtime are all grouped by their mean and they are going to be tested alongside
# the popularity mean to see if there's a trend.

# %%
# group features by their mean
popularity_mean = movies_df.groupby('revenue_rank').popularity.mean()
runtime_mean = movies_df.groupby('revenue_rank').runtime.mean()
budget_mean = movies_df.groupby('revenue_rank').budget.mean()

# %%
plt.plot(popularity_mean, label='popularity')
plt.plot(runtime_mean, label='runtime')
plt.plot(budget_mean, label='budget')
plt.legend()
plt.show();

# %% [markdown]
# From the above visual, it seems that

# %%
sns.lineplot(data=concatenated_df, x='popularity',y='revenue');

# %%
concatenated_df.director.value_counts()
# Out:
# John Carpenter               17
# Steven Soderbergh             9
# Clint Eastwood                6
# Paul W.S. Anderson            6
# Rob Zombie                    5
#                              ..
# Shana Feste                   1
# Andy Mitton|Jesse Holland     1
# Banksy                        1
# Marcos Efron                  1
# Hal Needham                   1
# Name: director, Length: 1176, dtype: int64

# %%
concatenated_df.query('director == "John Carpenter"')
# Out:
#       popularity      budget     revenue  runtime  vote_count  vote_average  \
# 607     0.745434  10000000.0    498974.0     88.0       166.0           5.9
# 757     0.451722  28000000.0  14010832.0     98.0       135.0           4.6
# 1704    0.659182   1000000.0  21378361.0     89.0       128.0           6.2
# 1848    0.637446  22000000.0  28744356.0    115.0        91.0           6.3
# 1854    0.560348         0.0  21200000.0    110.0       176.0           6.4
# 1865    0.385600         0.0         0.0     99.0        63.0           5.3
# 1870    0.354374  40000000.0  14358033.0     99.0        58.0           5.3
# 1874    1.003963   6000000.0  50000000.0     99.0       336.0           6.5
# 1886    0.891372  50000000.0  42277365.0     97.0       189.0           5.4
# 1914    2.355353  10000000.0  13782838.0    109.0       797.0           7.5
# 1925    0.626850  20000000.0         0.0    108.0       109.0           5.8
# ...

# %%
new_df = pd.concat([df_numeric, df_cleaned], axis='columns')
new_df.dropna(inplace=True)
new_df.drop(new_df[new_df['revenue'] == 0.0].index, inplace=True)
new_df.query('director == "John Carpenter"')
# Out:
#       popularity      budget     revenue  runtime  vote_count  vote_average  \
# 607     0.745434  10000000.0    498974.0     88.0       166.0           5.9
# 757     0.451722  28000000.0  14010832.0     98.0       135.0           4.6
# 1704    0.659182   1000000.0  21378361.0     89.0       128.0           6.2
# 1848    0.637446  22000000.0  28744356.0    115.0        91.0           6.3
# 1854    0.560348         0.0  21200000.0    110.0       176.0           6.4
# 1870    0.354374  40000000.0  14358033.0     99.0        58.0           5.3
# 1874    1.003963   6000000.0  50000000.0     99.0       336.0           6.5
# 1886    0.891372  50000000.0  42277365.0     97.0       189.0           5.4
# 1914    2.355353  10000000.0  13782838.0    109.0       797.0           7.5
# 1936    0.540362   4000000.0  13008928.0     94.0       229.0           6.9
# 1945    0.356749   3000000.0  14182492.0    101.0        62.0           6.5
# ...

# %%
new_df.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1065.000000  1.065000e+03  1.065000e+03  1065.000000  1065.000000
# mean      0.961598  2.625187e+07  6.145865e+07   105.071362   355.985915
# std       0.633206  2.640835e+07  6.753888e+07    14.494249   341.921515
# min       0.005391  0.000000e+00  1.000000e+01    63.000000    10.000000
# 25%       0.493944  4.000000e+06  7.500000e+06    94.000000    89.000000
# 50%       0.821206  1.900000e+07  3.850234e+07   103.000000   245.000000
# 75%       1.265401  4.000000e+07  9.260105e+07   114.000000   501.000000
# max       3.260581  1.200000e+08  3.173750e+08   152.000000  1608.000000
#
#        vote_average    budget_adj   revenue_adj
# count   1065.000000  1.065000e+03  1.065000e+03
# mean       6.136526  2.767820e+07  6.559090e+07
# std        0.751571  2.797859e+07  7.242408e+07
# min        3.800000  0.000000e+00  1.000000e+01
# 25%        5.600000  4.573802e+06  7.871522e+06
# ...

# %%
bin_edges = [0.000620, 0.345226, 0.604388, 1.083957, 3.260581]

# %%
concatenated_df.groupby(['director', 'original_title', 'release_date','genres', 'runtime','popularity']).revenue.mean().sort_values(ascending=False).head(15)
# Out:
# director                          original_title                                                                       release_date  genres                                   runtime  popularity
# Anne Fletcher                     The Proposal                                                                         2009-06-01    Comedy|Romance|Drama                     108.0    1.895894      317375031.0
# Paul Tibbitt                      The SpongeBob Movie: Sponge Out of Water                                             2015-02-05    Family|Animation                         93.0     1.291013      311594032.0
# Steven Soderbergh                 Ocean's Thirteen                                                                     2007-06-07    Crime|Thriller                           122.0    1.414350      311312624.0
# ...

# %%
plt.plot(df_cleaned.director, df_cleaned.revenue, label='popularity')
plt.legend()
plt.show();
# Out:
# C:\Users\Carla\anaconda3\envs\eda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot(df_numeric.revenue, df_numeric.budget, label='revenue')
plt.plot(df_numeric.popularity, df_numeric.budget, label='popularity')
plt.plot(df_numeric.runtime, df_numeric.budget, label='runtime')
plt.legend()
plt.show();

# %%
df_numeric.hist(figsize=(10,10));

# %%
plt.plot(df_numeric.runtime, df_numeric.revenue, label='revenue')
plt.plot(df_numeric.runtime, df_numeric.budget, label='budget')
plt.plot(df_numeric.runtime, df_numeric.popularity, label='popularity')
plt.legend()
plt.show();

# %%
sns.catplot(x=df_numeric.popularity, y=df_numeric.revenue, data=df_numeric);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [279], in <cell line: 1>()
# ----> 1 sns.catplot(x=df_numeric.popularity, y=df_numeric.revenue, data=df_numeric)
#
# File ~\anaconda3\envs\eda\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
df.tail()

# %%
g = df.groupby('release_date')['revenue'].mean().sort_values(ascending=False).head(7)
g.plot(figsize=(15,15));
# high_revenue = df.query('revenue >= ')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1992 entries, 1970-01-01 00:00:00.000002015 to 1970-01-01 00:00:00.000001978
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   popularity      1992 non-null   float64
#  1   budget          1992 non-null   int64
#  2   revenue         1992 non-null   int64
#  3   original_title  1992 non-null   object
#  4   cast            1992 non-null   object
#  5   director        1992 non-null   object
#  6   tagline         1992 non-null   object
#  7   keywords        1992 non-null   object
#  8   runtime         1992 non-null   int64
#  9   genres          1992 non-null   object
#  10  prod_companies  1992 non-null   object
#  11  vote_count      1992 non-null   int64
#  12  vote_average    1992 non-null   float64
#  13  release_year    1992 non-null   datetime64[ns]
#  14  budget_adj      1992 non-null   float64
# ...

# %%
df['popularity_rank'] =

# %% [markdown]
# ### Conclusions

# %%
def asses_data():

# %%
# Split the row with more than one genre into different rows

from itertools import chain

# Return list from series of '|'-separated strings
def chainer(s):
    return list(chain.from_iterable(s.str.split('|')))

# Calculate lengths of splits
lens = df_genres['genres'].str.split('|').map(len)

# Create new dataframe, repeating or chaining as appropriate
df_genres = pd.DataFrame({'release_year': np.repeat(df_genres['release_year'], lens),                       
                          'genres': chainer(df_genres['genres']),
                          'popularity': np.repeat(df_genres['popularity'], lens)})

df_genres.head()

# %%
# Aggregate years into decades
bin_edges = [1960, 1970, 1980, 1990, 2000, 2010, 2015]
bin_names = ['1960s', '1970s', '1980s', '1990s', '2000s', '2010s']
movies_df['decade'] = pd.cut(df['release_year'], bin_edges, labels=bin_names)
movies_df.head()

# %%
decades = movies_df.groupby('genres').revenue.mean()
decades.head()

# %%
plt.bar(decades.index, decades.values)
plt.title('The comparison of revenue among decades')
plt.xlabel('Decade')
plt.ylabel('Revenue')

plt.show()
